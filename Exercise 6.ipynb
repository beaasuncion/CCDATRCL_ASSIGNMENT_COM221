# %% [markdown]
# # Exercise 6

# %% [markdown]
# #### Pre-defined code

# %%
class Node:
    def __init__(self, item):
        self.left = None
        self.right = None
        self.val = item

# %%
def inorder(root):

    if root:
        # Traverse left
        inorder(root.left)
        # Traverse root
        print(str(root.val) + "->", end='')
        # Traverse right
        inorder(root.right)

def postorder(root):

    if root:
        # Traverse left
        postorder(root.left)
        # Traverse right
        postorder(root.right)
        # Traverse root
        print(str(root.val) + "->", end='')

def preorder(root):

    if root:
        # Traverse root
        print(str(root.val) + "->", end='')
        # Traverse left
        preorder(root.left)
        # Traverse right
        preorder(root.right)

# %% [markdown]
# #### 1. Construct Create your own company org chart and put yourself as CEO.
#
# Using a Tree data structure,
#
# - Assign yourself as CEO
#
# - Assign any of your classmate as HR Director
# - Assign any of your classmate as Sales Director
#
# - Assign any of your classmate as trainee. His/her boss is the HR Director
# - Assign any of your classmate as a staff and trainee. Their boss is the Sales Director

# %% [markdown]
# <img src="https://thumbs.dreamstime.com/z/cartoon-organization-chart-some-company-93778925.jpg"/>

# %%
ceo = Node("Beatriz")
hr_director = Node("Brix")
sales_director = Node("Uriel")
hr_trainee = Node("Jillian")
sales_staff = Node("Allen")
sales_trainee = Node("Brando")

ceo.left = hr_director
ceo.right = sales_director

hr_director.left = hr_trainee

sales_director.left = sales_staff
sales_director.right = sales_trainee

# %% [markdown]
# #### 2. Traverse the tree in in-order traversal

# %%
inorder(ceo)
# Out:
# Jillian->Brix->Beatriz->Allen->Uriel->Brando->

# %% [markdown]
# #### 3. Traverse the tree in pre-order traversal

# %%
preorder(ceo)
# Out:
# Beatriz->Brix->Jillian->Uriel->Allen->Brando->

# %% [markdown]
# #### 4. Traverse the tree in post-order traversal

# %%
postorder(ceo)
# Out:
# Jillian->Brix->Allen->Brando->Uriel->Beatriz->
