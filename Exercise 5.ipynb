# %% [markdown]
# # Exercise 5

# %% [markdown]
# #### 1. Create a dictionary of your 10 favorite songs.

# %% [markdown]
# Example:
#
# |KEY|VALUE|
# |---|---|
# |001|My Love|
# |002|Like a rose|

# %%
mydictionary = {
  "001": "My Love",
  "002": "Like a rose",
  "003": "Nothing",
  "004": "Lugaw",
  "005": "Mahal Kape tayo",
  "006": "Nahuhulog na sa'ýo",
  "007": "Invisible string",
  "008": "the Way I Loved You",
  "009": "Jump Then Fall",
  "010": "Our Song",
}
print(mydictionary)
# Out:
# {'001': 'My Love', '002': 'Like a rose', '003': 'Nothing', '004': 'Lugaw', '005': 'Mahal Kape tayo', '006': "Nahuhulog na sa'ýo", '007': 'Invisible string', '008': 'the Way I Loved You', '009': 'Jump Then Fall', '010': 'Our Song'}

# %% [markdown]
# #### 2. Loop through the dictionary by its **key** and **value**

# %%
for x, y in mydictionary.items():
  print(x, y)
# Out:
# 001 My Love
# 002 Like a rose
# 003 Nothing
# 004 Lugaw
# 005 Mahal Kape tayo
# 006 Nahuhulog na sa'ýo
# 007 Invisible string
# 008 the Way I Loved You
# 009 Jump Then Fall
# 010 Our Song

# %% [markdown]
# #### 3. Add one additional song

# %%
mydictionary["011"] = "Cornelia Street"
mydictionary
# Out:
# {'001': 'My Love',
#  '002': 'Like a rose',
#  '003': 'Nothing',
#  '004': 'Lugaw',
#  '005': 'Mahal Kape tayo',
#  '006': "Nahuhulog na sa'ýo",
#  '007': 'Invisible string',
#  '008': 'the Way I Loved You',
#  '009': 'Jump Then Fall',
#  '010': 'Our Song',
#  '011': 'Cornelia Street'}

# %% [markdown]
# #### 4. Remove one song

# %%
mydictionary.pop("001")
mydictionary
# Out:
# {'002': 'Like a rose',
#  '003': 'Nothing',
#  '004': 'Lugaw',
#  '005': 'Mahal Kape tayo',
#  '006': "Nahuhulog na sa'ýo",
#  '007': 'Invisible string',
#  '008': 'the Way I Loved You',
#  '009': 'Jump Then Fall',
#  '010': 'Our Song',
#  '011': 'Cornelia Street'}

# %% [markdown]
# #### 5. Create a nested dictionary of your 10 favorite songs with 5 genres. Display all of the items of the nested dictionary
#
# - Each nested dictionary's key should be the genre of the song
# - Put each song in their respective genre

# %% [markdown]
# Example:
#
#
# |KEY|VALUE|
# |---|---|
# |Pop|{001, Baby}|
# |Rock|{001, Enter Sandman}|

# %%
mydictionary = {
  "RnB" : {
    "001" : "My Love",
    "002" : "Like a rose",
    "003" : "Nothing"
  },

  "Rap" : {
    "001" : "Gento",
    "002" : "City Girl"
  },

  "Opm" : {
    "001" : "Lugaw",
    "002" : "Mahal Kape tayo",
    "003" : "Nahuhulog na sa'ýo"
  },

  "Pop" : {
    "001" : "Invisible string",
    "002" : "the Way I Loved You",
    "003" : "Jump Then Fall",
    "004" : "Our Song",
    "005" : "Cornelia Street"
    }
  }

# %%
print(mydictionary)
# Out:
# {'RnB': {'001': 'My Love', '002': 'Like a rose', '003': 'Nothing'}, 'Rap': {'001': 'Gento', '002': 'City Girl'}, 'Opm': {'001': 'Lugaw', '002': 'Mahal Kape tayo', '003': "Nahuhulog na sa'ýo"}, 'Pop': {'001': 'Invisible string', '002': 'the Way I Loved You', '003': 'Jump Then Fall', '004': 'Our Song', '005': 'Cornelia Street'}}

# %% [markdown]
# #### 6. Print the first song of the first genre

# %%
print(mydictionary["RnB"]["001"])
# Out:
# My Love

# %% [markdown]
# #### 7. Print the first song of the last genre

# %%
print(mydictionary["Pop"]["005"])
# Out:
# Cornelia Street
